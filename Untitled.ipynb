# %%
from file_reader import read_csv_url

# Read in file: 
# Load from URL
url_airbnb = "https://orca.casa.ucl.ac.uk/~jreades/data/20250615-London-listings.csv.gz"
df_airbnb = read_csv_url(url_airbnb, compression="gzip")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from file_reader import read_csv_url
#       3 # Read in file:
#       4 # Load from URL
#       5 url_airbnb = "https://orca.casa.ucl.ac.uk/~jreades/data/20250615-London-listings.csv.gz"
#
# File ~/work/CASA/FSDS_Groupwork/file_reader.py:2
#       1 import pandas as pd
# ----> 2 import janitor
#       3 import matplotlib.pyplot as plt
#       4 from typing import Optional
#
# File /opt/conda/lib/python3.12/site-packages/janitor/__init__.py:6
#       3 import pandas_flavor as pf  # noqa: F401
#       5 from .accessors import *  # noqa: F403, F401
# ----> 6 from .functions import *  # noqa: F403, F401
#       7 from .io import *  # noqa: F403, F401
#       8 from .math import *  # noqa: F403, F401
#
# File /opt/conda/lib/python3.12/site-packages/janitor/functions/__init__.py:25
#      23 from .change_index_dtype import change_index_dtype
#      24 from .change_type import change_type
# ---> 25 from .clean_names import clean_names
#      26 from .coalesce import coalesce
#      27 from .collapse_levels import collapse_levels
#
# File /opt/conda/lib/python3.12/site-packages/janitor/functions/clean_names.py:12
#       9 from pandas.api.types import is_scalar
#      11 from janitor.errors import JanitorError
# ---> 12 from janitor.functions.select import get_index_labels
#      13 from janitor.functions.utils import _is_str_or_cat
#      14 from janitor.utils import deprecated_alias
#
# File /opt/conda/lib/python3.12/site-packages/janitor/functions/select.py:330
#     266     """Method-chainable selection of rows.
#     267
#     268     It accepts a string, shell-like glob strings `(*string*)`,
#    (...)    325         A pandas DataFrame with the specified rows selected.
#     326     """  # noqa: E501
#     327     return _select(df, rows=list(args), invert=invert)
# --> 330 @pf.register_groupby_method
#     331 @pf.register_dataframe_method
#     332 @pf.register_series_method
#     333 @deprecated_alias(rows="index")
#     334 def select(
#     335     df: pd.DataFrame | pd.Series | DataFrameGroupBy,
#     336     *args: tuple,
#     337     index: Any = None,
#     338     columns: Any = None,
#     339     axis: str = "columns",
#     340     invert: bool = False,
#     341 ) -> pd.DataFrame | pd.Series | DataFrameGroupBy:
#     342     """Method-chainable selection of rows and/or columns.
#     343
#     344     It accepts a string, shell-like glob strings `(*string*)`,
#    (...)    440         A pandas DataFrame or Series with the specified rows and/or columns selected.
#     441     """  # noqa: E501
#     442     if args and isinstance(df, DataFrameGroupBy):
#
# File /opt/conda/lib/python3.12/site-packages/lazy_loader/__init__.py:94, in attach.<locals>.__getattr__(name)
#      92     return attr
#      93 else:
# ---> 94     raise AttributeError(f"No {package_name} attribute {name}")
#
# AttributeError: No pandas_flavor attribute register_groupby_method
