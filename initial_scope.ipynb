# %% [markdown]
# ## Initial project scope
#
# #### * Background:
#
# Broken laws (overstanding, misuse of Airbnb, finantial regulations)
#       - Impacts on gentrification (rising costs on long-term rents and local comerce)
#       - Impacts on the neighbourhood
#
# #### * Research question:
#
# Is Airbnb 'out of control' in London and should the Mayor adopt the plan to force all professional landlords to register their properties and face higher Council Tax rates ?
#
# #### * Evaluation of used datasets:
#
# #### * Explanation of the intended data wrangling:
#
# #### * Plan for the spatial data analysis:
#
#   + 0) General data comprehension
#
#     - import libraries
#     - Read and inspect data (missing data, geographies, time ranges, note limitations)
#     - Clean data
#
#   + 1) Is Airbnb ‘out of control’ in London?
#
#     - Define out of control:
#       - (literature)Broken laws (overstanding, misuse of Airbnb, finantial regulations)
#       - (literature)Impacts on gentrification (rising costs on long-term rents and local comerce)
#       - (literature)Impacts on the neighbourhood (garbage, sound polution, correlation to crime (rise in turism = rise in crime?),
#       - (code) professor landlords
#       - (code) overstaing
#       - (code) borough income x average london income (boroughs to pay attention)
#     - Produce two clear visuals:
#       ✔ Map of Airbnb density by borough
#       ✔ Chart of entire-home listings vs private rooms
#       ✔ Trend of Airbnb listings over time
#     - Write 2–3 paragraphs interpreting the visuals for a political audience.
#
#   + 2) How many professional landlords are there?
#
#     - Define “professional landlord”
#       - number of renting days
#       - number of properties (2 or more from the same landlord)
#     - Justify threshold using literature or a borrowed assumption
#     - Write this logic out clearly.
#     - Count hosts by number of listings.
#     - Produce:
#       ✔ Histogram of distibution on listings per host
#       ✔ Table summarising number of hosts with >1, >3, >5 properties
#     - Write interpretation.
#
#   + 3) How many properties would be affected by the opposition’s proposal?
#
#     - Proposal targets “professional landlords” → define threshold
#       - professional landlors
#       - travelers
#       - positive impact of the local residents
#       - negsative impact on housing prices
#       - compare costs between hotels and professional airbnbs (impact that taxes will have on coasts)
#       - calculate the impact of taxes, assuming that they are increaning airbnb costs
#     - Write assumptions + justification.
#     - Calculate number of listings linked to “professional hosts.”
#     - Produce 1–2 visuals showing:
#       ✔ Number of properties affected (bar chart or table)
#       ✔ Spatial distribution (borough comparison)
#     - Write interpretation
#
#   + 4) What are the likely pros and cons of the opposition’s proposal (for the Mayor, for residents, and for the city)?
#
#     - Write bullets for three groups: Mayor, Residents, City (wider economy + housing system)
#     - Draw on your Q1–Q3 analysis:
#       - Could higher Council Tax reduce Airbnb supply?
#       - Could it push professional landlords to long-term rental market?
#       - Might it create unintended consequences (evasion, misreporting)?
#     - Turn bullet points into 3–5 paragraphs.
#     - Add 1–2 citations for political/economic context.
#
#   + 5) Can the story be reframed as a positive one about social mobility or housing opportunity?
#     - Ideas:
#         - Reframe story as restoring social mobility → affordable housing return
#         - Professionalising hosting → safer, better regulated market?
#         - Supporting neighbourhood economies with fair taxation?
#     - Write 2–3 paragraphs.
#
# #### * Constraints around the data:
#
#     - Write Assumptions + Data Limitations section (10% of the grade)
#     - Include:
#         - Why Airbnb dataset is incomplete
#         - Why assumptions were necessary
#         - Confidence level in numbers
#         - What data the Mayor would need to decide properly
#
# ### References
#     - Build your BibTeX file
#     - Add the four key provided references.
#     - Add at least 4–6 new citations you will likely use (Airbnb research, London housing, professional landlords, rent-gap theory).
#     - Confirm citation works inside Quarto.
